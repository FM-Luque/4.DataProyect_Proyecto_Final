# %% [markdown]
# ### FASE 1. Carga e integración de datos
#
# **Proyecto:** Análisis Exploratorio de Datos — Ingresos totales por ventas a clientes de un comercio.
#
# **Objetivo de esta fase:**
# Importar los datos desde las distintas fuentes disponibles y preparar un único dataset consolidado sobre el que trabajar en las siguientes fases (limpieza, EDA e informe).
#
# **Fuentes de datos:**
# - `clientes.csv` → información de los clientes  (edad, estado civil, ingresos, ciudad, , etc.)
# - `ventas.xlsx` → 5 hojas: 1 hoja con los productos y la información de las ventas, repartidas en 4 hojas (2022, 2023, 2024, 2025)

# %% [markdown]
# ### 1️⃣ Importar librerías

# %%
import pandas as pd
import numpy as np

# Para que se muestren todas las columnas al inspeccionar los DataFrames
pd.set_option('display.max_columns', None)

# %%
# Libreria de Tratamiento de Datos
import pandas as pd
from IPython.display import display

# Exploracion de Archivos
import sys
sys.path.append('../') # para que busque en carpeta src 
from src import sp_carga_integracion as ci

# Funcion personalizada para asegurarnos que aparezcan todas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 2️⃣ Cargar `clientes.csv`
# Este archivo contiene la informacion de los clientes.

# %%
df_clientes = pd.read_csv(r"../data/raw/clientes.csv")

# %% [markdown]
# #### Comprobación de la carga

# %%
# Primeras 5 filas
df_clientes.head()
# Out:
#    Unnamed: 0                                   id_  edad estado_civil      nivel_educativo  ingresos_anuales  tiene_hijos  adolescentes_en_casa     fecha_registro     ciudad region  latitude  longitude segmento_cliente  visitas_web_mes
# 0           0  b9e805ce-fe13-4ed5-82b1-286271529391  44.0       casado  grado universitario             30544          1.0                   0.0    20-octubre-2021  Barcelona   Este    39.838     -7.047       Recurrente                9
# 1           1  fa2c965b-9356-48b4-84f1-ee1bf213cee9  26.0       casado         bachillerato             46779          0.0                   0.0     21-agosto-2019     Malaga    Sur    39.741      0.201              VIP                4
# 2           2  0dd76b11-d81d-4df7-8ef0-23dab7ccf86f  50.0       Casado               master             22003          1.0                   0.0   3-diciembre-2020       Vigo  Norte    38.971     -6.919            Nuevo                8
# ...

# %%
#  Dimensiones del dataset
print("(Filas , Columnas):",df_clientes.shape)
# Out:
# (Filas , Columnas): (8000, 15)

# %%
# Nombres de las columnas
print("El archivo df_clientes esta compuesto por las columnas:\n",df_clientes.columns)
# Out:
# El archivo df_clientes esta compuesto por las columnas:
#  Index(['Unnamed: 0', 'id_', 'edad', 'estado_civil', 'nivel_educativo', 'ingresos_anuales', 'tiene_hijos', 'adolescentes_en_casa', 'fecha_registro', 'ciudad', 'region', 'latitude', 'longitude', 'segmento_cliente', 'visitas_web_mes'], dtype='str')

# %%
# Tipos de datos y nulos por columnas
df_clientes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8000 non-null   int64
#  1   id_                   8000 non-null   str
#  2   edad                  7520 non-null   float64
#  3   estado_civil          7920 non-null   str
#  4   nivel_educativo       7680 non-null   str
#  5   ingresos_anuales      8000 non-null   int64
#  6   tiene_hijos           7840 non-null   float64
#  7   adolescentes_en_casa  8000 non-null   float64
#  8   fecha_registro        7960 non-null   str
#  9   ciudad                8000 non-null   str
#  10  region                8000 non-null   str
#  11  latitude              8000 non-null   float64
#  12  longitude             8000 non-null   float64
#  13  segmento_cliente      8000 non-null   str
#  14  visitas_web_mes       8000 non-null   int64
# ...

# %%
# Libreria de Tratamiento de Datos
import pandas as pd
from IPython.display import display

# Exploracion de Archivos
import sys
sys.path.append('../') # para que busque en carpeta src 
from src import sp_carga_integracion as ci 

# Funcion personalizada para asegurarnos que aparezcan todas las columnas
pd.set_option('display.max_columns', None)

# %%
df_clientes = pd.read_csv(r"../data/raw/clientes.csv")

# %%
ci.eda_preliminar(df_clientes)
# Out:
# 5 FILAS ALEATORIAS
#                                                       288                                   4352                                  401                                   3931                                  268
# Unnamed: 0                                             288                                  4352                                   401                                  3931                                   268
# id_                   24de636c-a3c1-486a-afc2-9681f7befa84  aaa54f66-f34f-4550-888c-1ff13547738b  1626101b-4813-40b2-bee4-1a7d82ee37c7  6ac3db09-9bfa-4cf6-9be9-6a42dc399304  e6f7e4ca-3251-484c-8f69-45caf6bf03fd
# edad                                                  36.0                                  41.0                                  43.0                                  50.0                                  41.0
# ...

# %% [markdown]
# **Observaciones iniciales de `df_clientes`:**
# - Aparece una columna `Unnamed: 0` que es un índice residual del archivo original y no aporta información → se eliminará.
# - La columna `fecha_registro` se han cargado como texto (`str`). Esto se corregirá en la **Fase 2 (Limpieza)**.
# - Hay columnas con valores nulos (`edad`, `estado_civil`, `nivel_educativo`, `tiene_hijos`, `fecha_registro`),se tratarán en la **Fase 2 (Limpieza)**.
# - Las columnas (`tiene_hijos`, `adolescentes_en_casa`) en una primera visual parecen variables binarias, se tratarán en la **Fase 2 (Limpieza)**.

# %% [markdown]
# #### 3️⃣ Cargar `ventas.csv`
#
# Este archivo contiene 5 hojas, la HOJA 1 con los productos dispoblibles en tienda, y las HOJAS 2 A 5 con las ventas realizadas en los años (2022, 2023, 2024, 2025).

# %%
# Comprobamos las hojas que tiene el Excel
excel_ventas = pd.ExcelFile(r"../data/raw/ventas.xlsx")
print("El excel ventas lo compone las Hojas:\n",excel_ventas.sheet_names)
# Out:
# El excel ventas lo compone las Hojas:
#  ['productos', '2022', '2023', '2024', '2025']

# %% [markdown]
# #### **Hoja Productos**

# %%
# Cargamos la hoja productos
df_productos = pd.read_excel(excel_ventas, sheet_name="productos")

# %%
# Primeras 5 filas
df_productos.head()
# Out:
#    Unnamed: 0 product_id categoria_producto            nombre_producto     marca costo_unitario precio_lista  peso_kg         proveedor  stock_disponible fecha_lanzamiento  rating_promedio_producto
# 0           0      P0001        Electronica  Auriculares Urbanix Basic   Urbanix          26,73        45,70     9.60  Global Supply SL               383      31-mayo-2020                      3.60
# 1           1      P0002        Electronica    Auriculares Urbanix Pro   Urbanix          47,97        77,93    11.86  Global Supply SL               392      8-marzo-2019                      3.29
# 2           2      P0003        Electronica       Auriculares Nova Max      Nova          49,49        98,89     8.54  Global Supply SL               317     16-junio-2023                      4.18
# 3           3      P0004        Electronica  Smartphone Norte&Co Basic  Norte&Co          60,57        95,49     3.60   Comercial Atlas               303     23-enero-2019                      2.94
# ...

# %%
#  Dimensiones del dataset
print("(Filas , Columnas):",df_productos.shape)
# Out:
# (Filas , Columnas): (90, 12)

# %%
# Nombres de las columnas
print("El archivo df_clientes esta compuesto por las columnas:\n",df_productos.columns)
# Out:
# El archivo df_clientes esta compuesto por las columnas:
#  Index(['Unnamed: 0', 'product_id', 'categoria_producto', 'nombre_producto', 'marca', 'costo_unitario', 'precio_lista', 'peso_kg', 'proveedor', 'stock_disponible', 'fecha_lanzamiento', 'rating_promedio_producto'], dtype='str')

# %%
# Tipos de datos y nulos por columnas
df_productos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                90 non-null     int64
#  1   product_id                90 non-null     str
#  2   categoria_producto        90 non-null     str
#  3   nombre_producto           90 non-null     str
#  4   marca                     89 non-null     str
#  5   costo_unitario            90 non-null     str
#  6   precio_lista              90 non-null     str
#  7   peso_kg                   90 non-null     float64
#  8   proveedor                 90 non-null     str
#  9   stock_disponible          90 non-null     int64
#  10  fecha_lanzamiento         90 non-null     str
#  11  rating_promedio_producto  88 non-null     float64
# dtypes: float64(2), int64(2), str(8)
# memory usage: 15.4 KB

# %% [markdown]
# **Observaciones iniciales de `df_productos`:**
# - Aparece una columna `Unnamed: 0` que es un índice residual del archivo original y no aporta información → se eliminará.
# - La columna `fecha_lanzamiento` se ha cargado como texto (`str`).Se corregirá en la **Fase 2 (Limpieza)**.
# - Hay dos columna con valores nulos (`rating_promedio_producto`, `marca`),se tratarán en la **Fase 2 (Limpieza)**.
# - Las columnas (`costo_unitario`, `precio_lista`) se cargaron como texto (`str`), se tratarán en la **Fase 2 (Limpieza)**.
# - Se observa que la `columna product_id` esta relacionada con las Hojas 2022, 2023, 2024 ,2025, se comprobara antes de unirlas.

# %% [markdown]
# #### **Hojas 2022, 2023, 2024 ,2025**

# %%
# Cargamos cada hoja por separado
df_2022 = pd.read_excel(excel_ventas,sheet_name="2022")
df_2023 = pd.read_excel(excel_ventas,sheet_name="2023")
df_2024 = pd.read_excel(excel_ventas,sheet_name="2024")
df_2025 = pd.read_excel(excel_ventas,sheet_name="2025")

# %%
#  Dimensiones del dataset
for año, df in [("2022", df_2022), ("2023", df_2023), ("2024", df_2024), ("2025", df_2025)]:
    print(f"Año {año}: tiene {df.shape[0]} Filas y {df.shape[1]} Columnas ")
# Out:
# Año 2022: tiene 13000 Filas y 14 Columnas
# Año 2023: tiene 13000 Filas y 14 Columnas
# Año 2024: tiene 13000 Filas y 14 Columnas
# Año 2025: tiene 13000 Filas y 14 Columnas

# %%
# Nombres de las columnas
for año, df in [("2022", df_2022), ("2023", df_2023), ("2024", df_2024), ("2025", df_2025)]:
    print(f"Columnas de {año}: {df.columns.tolist()}")
# Out:
# Columnas de 2022: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal']
# Columnas de 2023: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal']
# Columnas de 2024: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal']
# Columnas de 2025: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal']

# %%
df_2022.sample(3)
# Out:
#       Unnamed: 0  order_id                                   id_ product_id       fecha_pedido  cantidad precio_unitario  descuento importe_total         metodo_pago  envio_gratis  calificacion devuelto          canal
# 113          113       114  9a72ca28-d0e2-4b02-9ab8-b7596db82d12      P0076       29-mayo-2022         2           30,71       0.05         58,35   Tarjeta de debito             0           NaN       no      App movil
# 8448        8448      8449  38178c1a-9f6c-4467-a177-4bdf6dcaa504      P0073  16-diciembre-2022         1           52,74       0.15         44,83       transferencia             0           4.0       NO            Web
# 6460        6460      6461  fd58670b-abfa-4ca4-8b89-839adfa7edd7      P0027       5-marzo-2022         1           72,00       0.00         72,00  TARJETA DE CREDITO             0           2.0       no  Tienda fisica

# %%
df_2023.sample(3)
# Out:
#        Unnamed: 0  order_id                                   id_ product_id        fecha_pedido  cantidad precio_unitario  descuento importe_total         metodo_pago  envio_gratis  calificacion devuelto        canal
# 12549       12549     25550  3c3df7fe-cf9e-4f03-875e-a5e00bbbdddd      P0004  23-septiembre-2023         3           80,12        0.0        240,35                 NaN             0           4.0       NO  Marketplace
# 10147       10147     23148  77020642-ce88-4cfb-a531-d4a35b7df027      P0022    5-noviembre-2023         2           50,47        0.0        100,94  tarjeta de credito             0           3.0       si          Web
# 10289       10289     23290  a187774a-5935-45d4-8f74-1b58749e6ad4      P0069      9-febrero-2023         1           15,42        0.0         15,42              paypal             0           NaN       NO  Marketplace

# %%
df_2024.sample(3)
# Out:
#       Unnamed: 0  order_id                                   id_ product_id       fecha_pedido  cantidad precio_unitario  descuento importe_total         metodo_pago  envio_gratis  calificacion devuelto          canal
# 7912        7912     33913  8d9f5561-3e11-4aed-a2b2-2138b170c539      P0023  29-diciembre-2024         3           14,01        0.0         42,02   Tarjeta de debito             1           4.0       NO      App movil
# 6874        6874     32875  572dad43-8536-4d2e-93e7-d8b7daa55813      P0082       14-mayo-2024         1           33,38        0.0         33,38   tarjeta de debito             1           5.0       no    Marketplace
# 5405        5405     31406  5a267885-0061-4a7c-9b35-a9c82c5ebe65      P0023   8-noviembre-2024         5           41,24        0.0        206,20  Tarjeta de credito             0           NaN       no  Tienda fisica

# %%
df_2025.sample(3)
# Out:
#        Unnamed: 0  order_id                                   id_ product_id   fecha_pedido  cantidad precio_unitario  descuento importe_total         metodo_pago  envio_gratis  calificacion devuelto          canal
# 5327         5327     44328  fd0201b9-5d73-4ab0-a4dd-588fe9af6c21      P0075   7-marzo-2025         1           28,71       0.05         27,27              PAYPAL             0           4.0       NO      App movil
# 3042         3042     42043  74c12c1f-4c77-4d6f-9086-9babf977c70e      P0010   5-junio-2025         1           50,98       0.05         48,43  tarjeta de credito             0           2.0       no      App movil
# 10749       10749     49750  79f00394-7ed1-41da-ac3e-431158f5ec6a      P0022  7-agosto-2025         3           50,19       0.05        143,04   Tarjeta de debito             0           2.0       no  Tienda fisica

# %%
df_2022.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       13000 non-null  int64
#  1   order_id         13000 non-null  int64
#  2   id_              13000 non-null  str
#  3   product_id       13000 non-null  str
#  4   fecha_pedido     13000 non-null  str
#  5   cantidad         13000 non-null  int64
#  6   precio_unitario  13000 non-null  str
#  7   descuento        13000 non-null  float64
#  8   importe_total    13000 non-null  str
#  9   metodo_pago      12805 non-null  str
#  10  envio_gratis     13000 non-null  int64
#  11  calificacion     11125 non-null  float64
#  12  devuelto         13000 non-null  str
#  13  canal            13000 non-null  str
# dtypes: float64(2), int64(4), str(8)
# memory usage: 2.5 MB

# %%
df_2023.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       13000 non-null  int64
#  1   order_id         13000 non-null  int64
#  2   id_              13000 non-null  str
#  3   product_id       13000 non-null  str
#  4   fecha_pedido     13000 non-null  str
#  5   cantidad         13000 non-null  int64
#  6   precio_unitario  13000 non-null  str
#  7   descuento        13000 non-null  float64
#  8   importe_total    13000 non-null  str
#  9   metodo_pago      12805 non-null  str
#  10  envio_gratis     13000 non-null  int64
#  11  calificacion     11072 non-null  float64
#  12  devuelto         13000 non-null  str
#  13  canal            13000 non-null  str
# dtypes: float64(2), int64(4), str(8)
# memory usage: 2.5 MB

# %%
df_2024.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       13000 non-null  int64
#  1   order_id         13000 non-null  int64
#  2   id_              13000 non-null  str
#  3   product_id       13000 non-null  str
#  4   fecha_pedido     13000 non-null  str
#  5   cantidad         13000 non-null  int64
#  6   precio_unitario  13000 non-null  str
#  7   descuento        13000 non-null  float64
#  8   importe_total    13000 non-null  str
#  9   metodo_pago      12805 non-null  str
#  10  envio_gratis     13000 non-null  int64
#  11  calificacion     11053 non-null  float64
#  12  devuelto         13000 non-null  str
#  13  canal            13000 non-null  str
# dtypes: float64(2), int64(4), str(8)
# memory usage: 2.5 MB

# %%
df_2025.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       13000 non-null  int64
#  1   order_id         13000 non-null  int64
#  2   id_              13000 non-null  str
#  3   product_id       13000 non-null  str
#  4   fecha_pedido     13000 non-null  str
#  5   cantidad         13000 non-null  int64
#  6   precio_unitario  13000 non-null  str
#  7   descuento        13000 non-null  float64
#  8   importe_total    13000 non-null  str
#  9   metodo_pago      12805 non-null  str
#  10  envio_gratis     13000 non-null  int64
#  11  calificacion     10977 non-null  float64
#  12  devuelto         13000 non-null  str
#  13  canal            13000 non-null  str
# dtypes: float64(2), int64(4), str(8)
# memory usage: 2.5 MB

# %% [markdown]
# **Observaciones iniciales de `df_2022, df_2023, df_2024, df_2025`:**
# - Aparece una columna `Unnamed: 0` que es un índice residual del archivo original y no aporta información → se eliminará.
# - La columna `fecha_pedido` se ha cargado como texto (`str`).Se corregirá en la **Fase 2**.
# - Hay dos columnas con valores nulos (`metodo_pago`,`calificacion` ),se tratarán en la **Fase 2**.
# - Las columnas (`precio_unitario`, `importe_total`) se cargaron como texto (`str`), se tratarán en la **Fase 2**.
# - La columna (`envio_gratis`) en una primera visual parece una variable binaria, se tratarán en la **Fase 2**.
# - Se observa que la `columna product_id` esta relacionada con las Hojas 2022, 2023, 2024 ,2025, se comprobara antes de unirlas.

# %% [markdown]
# #### 4️⃣ Unir  `df_2022, df_2023, df_2024, df_2025` del archivo `ventas.csv`
#
# Como las 4 hojas tienen exactamente las mismas columnas y representan el mismo tipo de información, las unimos verticalmente con pd.concat().
#
# Antes de unirlas, añadimos una columna `hoja_origen` para no perder la trazabilidad de qué hoja proviene cada registro (nos sera útil más adelante).

# %%
# Añadimos una columna que identifique el año/hoja de origen antes de concatenar
df_2022["hoja_origen"] = "2022"
df_2023["hoja_origen"] = "2023"
df_2024["hoja_origen"] = "2024"
df_2025["hoja_origen"] = "2025"

# %%
# Verificamos que se ha añadido la columna "hoja_origen"
#  Dimensiones del dataset
for año, df in [("2022", df_2022), ("2023", df_2023), ("2024", df_2024), ("2025", df_2025)]:
    print(f"Año {año}: tiene {df.shape[0]} Filas y {df.shape[1]} Columnas ")
# Out:
# Año 2022: tiene 13000 Filas y 15 Columnas
# Año 2023: tiene 13000 Filas y 15 Columnas
# Año 2024: tiene 13000 Filas y 15 Columnas
# Año 2025: tiene 13000 Filas y 15 Columnas

# %%
# Nombres de las columnas
for año, df in [("2022", df_2022), ("2023", df_2023), ("2024", df_2024), ("2025", df_2025)]:
    print(f"Columnas de {año}: {df.columns.tolist()}")
# Out:
# Columnas de 2022: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal', 'hoja_origen']
# Columnas de 2023: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal', 'hoja_origen']
# Columnas de 2024: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal', 'hoja_origen']
# Columnas de 2025: ['Unnamed: 0', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal', 'hoja_origen']

# %% [markdown]
# #### Concatenamos

# %%
df_ventas = pd.concat([df_2022, df_2023, df_2024,df_2025], ignore_index=True)

# %%
df_ventas.sample(5)
# Out:
#        Unnamed: 0  order_id                                   id_ product_id        fecha_pedido  cantidad precio_unitario  descuento importe_total         metodo_pago  envio_gratis  calificacion devuelto          canal hoja_origen
# 7592         7592      7593  ea4f1702-f8d1-4772-9d69-d1e505bf40e4      P0019  23-septiembre-2022         3           46,65       0.00        139,96  Tarjeta de credito             0           5.0       NO  Tienda fisica        2022
# 9764         9764      9765  752ac8a0-ae46-4d2a-ab21-ef4880c1cd5d      P0065   2-septiembre-2022         4           48,97       0.00        195,90  tarjeta de credito             0           NaN       no            Web        2022
# 4844         4844      4845  5aca8855-4b53-4101-8763-49a6e59c06e2      P0060       21-julio-2022         1           98,82       0.30         69,17   Tarjeta de debito             1           5.0       NO            Web        2022
# ...

# %% [markdown]
# #### Comprobación de la concatenación

# %%
# La suma de filas debe coincidir con la suma de las 3 hojas por separado
print("Filas 2022 + 2023 + 2024 + 2025:", len(df_2022) + len(df_2023) + len(df_2024) + len(df_2025))
print("Filas df_ventas:", len(df_ventas))
# Out:
# Filas 2022 + 2023 + 2024 + 2025: 52000
# Filas df_ventas: 52000

# %%
#  Dimensiones del dataset
print("(Filas , Columnas):",df_ventas.shape)
# Out:
# (Filas , Columnas): (52000, 15)

# %%
# Reviamos el df_ventas 
df_ventas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       52000 non-null  int64
#  1   order_id         52000 non-null  int64
#  2   id_              52000 non-null  str
#  3   product_id       52000 non-null  str
#  4   fecha_pedido     52000 non-null  str
#  5   cantidad         52000 non-null  int64
#  6   precio_unitario  52000 non-null  str
#  7   descuento        52000 non-null  float64
#  8   importe_total    52000 non-null  str
#  9   metodo_pago      51220 non-null  str
#  10  envio_gratis     52000 non-null  int64
#  11  calificacion     44227 non-null  float64
#  12  devuelto         52000 non-null  str
#  13  canal            52000 non-null  str
#  14  hoja_origen      52000 non-null  str
# dtypes: float64(2), int64(4), str(9)
# memory usage: 10.6 MB

# %% [markdown]
# **Observaciones iniciales de `df_ventas`:**
# - Aparece una columna `Unnamed: 0` que es un índice residual del archivo original y no aporta información → se eliminará.
# - La columna `fecha_pedido` se ha cargado como texto (`str`).Se corregirá en la **Fase 2**.
# - Hay dos columnas con valores nulos (`metodo_pago`,`calificacion` ),se tratarán en la **Fase 2**.
# - Las columnas (`precio_unitario`, `importe_total`) se cargaron como texto (`str`), se tratarán en la **Fase 2**.0
# - La columna (`envio_gratis`) en una primera visual parece una variable binaria, se tratarán en la **Fase 2**.
# - Se observa que la `columna product_id` esta relacionada con las Hojas 2022, 2023, 2024 ,2025, se comprobara antes de unirlas.

# %% [markdown]
# #### 5️⃣ Unir `df_ventas` con `df_productos`
#
# Como hemos observado ambos comparten la columna `producto_id`, por lo que uniremos con `merge()` y con `how="left"` para conservar todas las dilas de `df_ventas`

# %%
# Comprobamos si hay algún product_id en df_ventas que no exista en df_productos
set(df_ventas["product_id"]) - set(df_productos["product_id"])
# Out:
# set()

# %%
df_ventas_productos = df_ventas.merge(df_productos, on="product_id", how="left")

# %%
print(len(df_ventas), len(df_ventas_productos))  # deberían ser iguales
df_ventas_productos.isnull().sum()  # si aparecen nulos en columnas de producto, algo no casó bien
# Out:
# 52000 52000
# Unnamed: 0_x                   0
# order_id                       0
# id_                            0
# product_id                     0
# fecha_pedido                   0
# cantidad                       0
# precio_unitario                0
# descuento                      0
# importe_total                  0
# metodo_pago                  780
# envio_gratis                   0
# calificacion                7773
# devuelto                       0
# canal                          0
# hoja_origen                    0
# Unnamed: 0_y                   0
# categoria_producto             0
# nombre_producto                0
# marca                        567
# costo_unitario                 0
# precio_lista                   0
# peso_kg                        0
# proveedor                      0
# stock_disponible               0
# fecha_lanzamiento              0
# rating_promedio_producto    1133
# dtype: int64

# %% [markdown]
# #### 6️⃣ Unimos df_ventas_productos con df_clientes
#
# Como hemos observado ambos comparten la columna `id_`, por lo que uniremos con `merge()` y con `how="left"` para conservar todas las dilas de `df_ventas_productos`

# %%
df_clientes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8000 non-null   int64
#  1   id_                   8000 non-null   str
#  2   edad                  7520 non-null   float64
#  3   estado_civil          7920 non-null   str
#  4   nivel_educativo       7680 non-null   str
#  5   ingresos_anuales      8000 non-null   int64
#  6   tiene_hijos           7840 non-null   float64
#  7   adolescentes_en_casa  8000 non-null   float64
#  8   fecha_registro        7960 non-null   str
#  9   ciudad                8000 non-null   str
#  10  region                8000 non-null   str
#  11  latitude              8000 non-null   float64
#  12  longitude             8000 non-null   float64
#  13  segmento_cliente      8000 non-null   str
#  14  visitas_web_mes       8000 non-null   int64
# ...

# %%
df_ventas_productos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52000 entries, 0 to 51999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0_x              52000 non-null  int64
#  1   order_id                  52000 non-null  int64
#  2   id_                       52000 non-null  str
#  3   product_id                52000 non-null  str
#  4   fecha_pedido              52000 non-null  str
#  5   cantidad                  52000 non-null  int64
#  6   precio_unitario           52000 non-null  str
#  7   descuento                 52000 non-null  float64
#  8   importe_total             52000 non-null  str
#  9   metodo_pago               51220 non-null  str
#  10  envio_gratis              52000 non-null  int64
#  11  calificacion              44227 non-null  float64
#  12  devuelto                  52000 non-null  str
#  13  canal                     52000 non-null  str
# ...

# %%
# Unir con df_clientes por la columna id_
df_final = df_ventas_productos.merge(df_clientes, on="id_", how="left")

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0_x', 'order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal', 'hoja_origen', 'Unnamed: 0_y', 'categoria_producto', 'nombre_producto', 'marca', 'costo_unitario', 'precio_lista', 'peso_kg', 'proveedor', 'stock_disponible', 'fecha_lanzamiento', 'rating_promedio_producto', 'Unnamed: 0', 'edad', 'estado_civil', 'nivel_educativo', 'ingresos_anuales', 'tiene_hijos', 'adolescentes_en_casa', 'fecha_registro', 'ciudad', 'region', 'latitude', 'longitude', 'segmento_cliente', 'visitas_web_mes'], dtype='str')

# %%
# Eliminamos las columnas Unnamed
df_final= df_final.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y","Unnamed: 0"])

# %%
# comprobamos 
df_final.columns
# Out:
# Index(['order_id', 'id_', 'product_id', 'fecha_pedido', 'cantidad', 'precio_unitario', 'descuento', 'importe_total', 'metodo_pago', 'envio_gratis', 'calificacion', 'devuelto', 'canal', 'hoja_origen', 'categoria_producto', 'nombre_producto', 'marca', 'costo_unitario', 'precio_lista', 'peso_kg', 'proveedor', 'stock_disponible', 'fecha_lanzamiento', 'rating_promedio_producto', 'edad', 'estado_civil', 'nivel_educativo', 'ingresos_anuales', 'tiene_hijos', 'adolescentes_en_casa', 'fecha_registro', 'ciudad', 'region', 'latitude', 'longitude', 'segmento_cliente', 'visitas_web_mes'], dtype='str')

# %%
df_final.shape
# Out:
# (52000, 37)

# %%
print("Numero de filas en df_clientes:", len(df_clientes))
print("numero de filas en df_ventas_productos es:", len(df_ventas_productos))
print("numero de filas en df_final es :", len(df_final))
# Out:
# Numero de filas en df_clientes: 8000
# numero de filas en df_ventas_productos es: 52000
# numero de filas en df_final es : 52000

# %%
df_final.head(3).T
# Out:
#                                                              0                                     1                                     2
# order_id                                                     1                                     2                                     3
# id_                       7ec28fa9-cad8-4f9a-a5b4-04a3f722c107  0f14d6ee-e853-448f-a20f-d6c933956321  5db0a392-f9b6-48c4-a1b0-bdd040ab4917
# product_id                                               P0086                                 P0086                                 P0001
# fecha_pedido                                 3-septiembre-2022                     18-noviembre-2022                         14-enero-2022
# cantidad                                                     4                                     1                                     1
# precio_unitario                                          27,29                                 68,24                                 25,84
# ...

# %%
# Comprobamos cuántos registros de la campaña son valores nulos, solo los registros con valores nulos  
nulos = df_final.isna().sum()
nulos[nulos>0].sort_values(ascending=False)
# Out:
# calificacion                7773
# edad                        3039
# nivel_educativo             2063
# rating_promedio_producto    1133
# tiene_hijos                 1038
# metodo_pago                  780
# marca                        567
# estado_civil                 524
# fecha_registro               253
# dtype: int64

# %%
nulos_prod = df_productos.isna().sum()
nulos_prod[nulos_prod > 0].sort_values(ascending=True)
# Out:
# marca                       1
# rating_promedio_producto    2
# dtype: int64

# %% [markdown]
# **Observaciones iniciales de `df_final`:**
# - Hay dos columnas con valores nulos (`marca`,`rating_promedio_producto`), aparecen 567 nulos en `marca` y 1133 nulos en `rating_promedio_producto` que no aparecian en df_productos, esto es debido a que se ha aumentado de 90 filas de `productos` a 52.000 filas de `ventas`, por lo que cada nulo de `productos` se ha repetido tantas veces como `ventas` tenga ese producto, se tratarán en la **Fase 2**.

# %% [markdown]
# ### 7️⃣ Guardar el dataset integrado
# Guardamos el resultado de esta fase como `01_datos_integrados` para poder continuar con la Fase 2 (Limpieza y transformación) sin tener que repetir la carga y el merge cada vez.

# %%
df_final.to_csv("../data/processed/01_datos_integrados.csv", index=False)
